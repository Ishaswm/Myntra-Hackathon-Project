# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics.pairwise import cosine_similarity

# %%
dtype_spec = {
    'department_id': 'str',
    'Brand': 'str',
    'Description': 'str',
    'Image_URL': 'str',
    'Category_by_gender': 'str'
}
df = pd.read_csv('projectdataset.csv', dtype=dtype_spec, low_memory=False)
# Use only the first 31,583 rows
df = df.head(31583)

# %%
df.head(30)
# Out:
#     order_id  user_id  order_number  product_id  add_to_cart_order  reordered  \
# 0    2425083    49125             1          17                  1          0
# 1    2425083    49125             1          91                  2          0
# 2    2425083    49125             1          36                  3          0
# 3    2425083    49125             1          83                  4          0
# 4    2425083    49125             1          83                  5          0
# 5    2425083    49125             1          91                  6          0
# 6    2425083    49125             1         120                  7          0
# 7    2425083    49125             1          59                  8          0
# 8    2425083    49125             1          35                  9          0
# 9    1944304   162867             1          37                  1          0
# 10   1944304   162867             1          24                  2          0
# 11   1944304   162867             1          83                  3          0
# 12   1944304   162867             1          84                  4          0
# 13   1944304   162867             1          91                  5          0
# 14   1944304   162867             1          24                  6          0
# 15   1944304   162867             1          24                  7          0
# 16   1944304   162867             1          24                  8          0
# 17   1944304   162867             1          21                  9          0
# 18   1944304   162867             1         112                 10          0
# 19   1944304   162867             1          24                 11          0
# 20   1944304   162867             1          24                 12          0
# 21   1944304   162867             1          24                 13          0
# 22   1201011   147243            14          94                  1          0
# 23   1201011   147243            14          83                  2          0
# 24   1201011   147243            14          83                  3          1
# 25   1201011   147243            14          24                  4          1
# 26   1201011   147243            14         120                  5          1
# 27   1201011   147243            14         120                  6          1
# 28   1201011   147243            14          91                  7          1
# 29   1201011   147243            14         120                  8          1
#
#    department_id       Brand  \
# 0             13   performax
# 1             16   performax
# 2             16  teamspirit
# 3              4   performax
# 4              4  teamspirit
# 5             16  teamspirit
# 6             16  teamspirit
# 7             15   performax
# 8             12   performax
# 9              1  teamspirit
# 10             4   performax
# 11             4   performax
# 12            16   performax
# 13            16   performax
# 14             4   performax
# 15             4   performax
# 16             4  teamspirit
# 17            16   performax
# 18             3  teamspirit
# 19             4   performax
# 20             4  teamspirit
# 21             4  teamspirit
# 22             7   performax
# 23             4  teamspirit
# 24             4  teamspirit
# 25             4  teamspirit
# 26            16  teamspirit
# 27            16  teamspirit
# 28            16   performax
# 29            16   performax
#
#                                           Description  \
# 0   Typographic Print Track Pants with Insert Pockets
# 1                        Low-Top Lace-Up Sports Shoes
# 2                        Colorblock Crew-Neck T-shirt
# 3        Camouflage Print Joggers with Insert Pockets
# 4            Reflective Colourblock Crew-Neck T-shirt
# 5                  Core Rib Joggers with Slip Pockets
# 6     Core Varsity Polo T-shirt with Contrast Tipping
# 7         Typographic Print Running Crew-Neck T-shirt
# 8                          Panelled Crew-Neck T-shirt
# 9                   Core rib bottom track charcoal xs
# 10         Logo Print Track Pants with Insert Pockets
# 11               Joggers with Zippered Insert Pockets
# 12              Flat-Front Shorts with Insert Pockets
# 13   Straight Running Track Pants with Insert Pockets
# 14      Typographic Print Quick-dry Crew-Neck T-shirt
# 15                        Dot Print Crew-Neck T-shirt
# 16    Core Varsity Polo T-shirt with Contrast Tipping
# 17          Brand Print Shorts with Elasticated Waist
# 18  Mid-Rise Cropped Slim Fit Track Pants with Ela...
# 19  Brand Print Straight Trackpants with Insert Po...
# 20                Reflective Print Coordinate Joggers
# 21                     Auto Striper Crew-Neck T-shirt
# 22      Typographic Print Shorts with Contrast Taping
# 23                        Heathered Crew-Neck T-shirt
# 24          Straight Track Pants with Contrast Piping
# 25                      Colourblock Crew-Neck T-shirt
# 26    Core Varsity Polo T-shirt with Contrast Tipping
# 27  Herringbone Mid-Rise Slim Fit Track Pants with...
# 28                    Graphic Print Crew-Neck T-shirt
# 29        Quickdry Unlined Running Windbreaker Jacket
#
#                                             Image_URL Category_by_gender  \
# 0   https://assets.ajio.com/medias/sys_master/root...                Men
# 1   https://assets.ajio.com/medias/sys_master/root...                Men
# 2   https://assets.ajio.com/medias/sys_master/root...                Men
# 3   https://assets.ajio.com/medias/sys_master/root...                Men
# 4   https://assets.ajio.com/medias/sys_master/root...                Men
# 5   https://assets.ajio.com/medias/sys_master/root...                Men
# 6   https://assets.ajio.com/medias/sys_master/root...                Men
# 7   https://assets.ajio.com/medias/sys_master/root...                Men
# 8   https://assets.ajio.com/medias/sys_master/root...                Men
# 9   https://assets.ajio.com/medias/sys_master/root...                Men
# 10  https://assets.ajio.com/medias/sys_master/root...                Men
# 11  https://assets.ajio.com/medias/sys_master/root...                Men
# 12  https://assets.ajio.com/medias/sys_master/root...                Men
# 13  https://assets.ajio.com/medias/sys_master/root...                Men
# 14  https://assets.ajio.com/medias/sys_master/root...                Men
# 15  https://assets.ajio.com/medias/sys_master/root...                Men
# 16  https://assets.ajio.com/medias/sys_master/root...                Men
# 17  https://assets.ajio.com/medias/sys_master/root...                Men
# 18  https://assets.ajio.com/medias/sys_master/root...                Men
# 19  https://assets.ajio.com/medias/sys_master/root...                Men
# 20  https://assets.ajio.com/medias/sys_master/root...                Men
# 21  https://assets.ajio.com/medias/sys_master/root...                Men
# 22  https://assets.ajio.com/medias/sys_master/root...                Men
# 23  https://assets.ajio.com/medias/sys_master/root...                Men
# 24  https://assets.ajio.com/medias/sys_master/root...                Men
# 25  https://assets.ajio.com/medias/sys_master/root...                Men
# 26  https://assets.ajio.com/medias/sys_master/root...                Men
# 27  https://assets.ajio.com/medias/sys_master/root...                Men
# 28  https://assets.ajio.com/medias/sys_master/root...                Men
# 29  https://assets.ajio.com/medias/sys_master/root...                Men
#
#       Category     action
# 0   Activewear       view
# 1   Activewear       view
# 2   Activewear       view
# 3   Activewear       view
# 4   Activewear       view
# 5   Activewear       view
# 6   Activewear       view
# 7   Activewear       view
# 8   Activewear       view
# 9   Activewear       view
# 10  Activewear       view
# 11  Activewear       view
# 12  Activewear       view
# 13  Activewear       view
# 14  Activewear       view
# 15  Activewear       view
# 16  Activewear       view
# 17  Activewear  addtocart
# 18  Activewear       view
# 19  Activewear  addtocart
# 20  Activewear       view
# 21  Activewear       view
# 22  Activewear       view
# 23  Activewear       view
# 24  Activewear       view
# 25  Activewear       view
# 26  Activewear       view
# 27  Activewear       view
# 28  Activewear       view
# 29  Activewear       view

# %%
action_map = {
    'view': 1,
    'add_to_cart': 2,
    'purchase': 3
}
df['action'] = df['action'].map(action_map)

# %%
df.head(10)
# Out:
#    order_id  user_id  order_number  product_id  add_to_cart_order  reordered  \
# 0   2425083    49125             1          17                  1          0
# 1   2425083    49125             1          91                  2          0
# 2   2425083    49125             1          36                  3          0
# 3   2425083    49125             1          83                  4          0
# 4   2425083    49125             1          83                  5          0
# 5   2425083    49125             1          91                  6          0
# 6   2425083    49125             1         120                  7          0
# 7   2425083    49125             1          59                  8          0
# 8   2425083    49125             1          35                  9          0
# 9   1944304   162867             1          37                  1          0
#
#   department_id       Brand  \
# 0            13   performax
# 1            16   performax
# 2            16  teamspirit
# 3             4   performax
# 4             4  teamspirit
# 5            16  teamspirit
# 6            16  teamspirit
# 7            15   performax
# 8            12   performax
# 9             1  teamspirit
#
#                                          Description  \
# 0  Typographic Print Track Pants with Insert Pockets
# 1                       Low-Top Lace-Up Sports Shoes
# 2                       Colorblock Crew-Neck T-shirt
# 3       Camouflage Print Joggers with Insert Pockets
# 4           Reflective Colourblock Crew-Neck T-shirt
# 5                 Core Rib Joggers with Slip Pockets
# 6    Core Varsity Polo T-shirt with Contrast Tipping
# 7        Typographic Print Running Crew-Neck T-shirt
# 8                         Panelled Crew-Neck T-shirt
# 9                  Core rib bottom track charcoal xs
#
#                                            Image_URL Category_by_gender  \
# 0  https://assets.ajio.com/medias/sys_master/root...                Men
# 1  https://assets.ajio.com/medias/sys_master/root...                Men
# 2  https://assets.ajio.com/medias/sys_master/root...                Men
# 3  https://assets.ajio.com/medias/sys_master/root...                Men
# 4  https://assets.ajio.com/medias/sys_master/root...                Men
# 5  https://assets.ajio.com/medias/sys_master/root...                Men
# 6  https://assets.ajio.com/medias/sys_master/root...                Men
# 7  https://assets.ajio.com/medias/sys_master/root...                Men
# 8  https://assets.ajio.com/medias/sys_master/root...                Men
# 9  https://assets.ajio.com/medias/sys_master/root...                Men
#
#      Category  action
# 0  Activewear     1.0
# 1  Activewear     1.0
# 2  Activewear     1.0
# 3  Activewear     1.0
# 4  Activewear     1.0
# 5  Activewear     1.0
# 6  Activewear     1.0
# 7  Activewear     1.0
# 8  Activewear     1.0
# 9  Activewear     1.0

# %%
# Verify the dataset contains necessary columns
required_columns = ['user_id', 'product_id', 'action', 'Category_by_gender', 'Brand', 'Image_URL']
missing_columns = [col for col in required_columns if col not in df.columns]
if missing_columns:
    raise ValueError(f"Dataset is missing required columns: {missing_columns}")

# Initialize the LabelEncoder
label_encoders = {
    'user_id': LabelEncoder(),
    'product_id': LabelEncoder()
}

# Fit and transform the user_id and product_id
df['user_id'] = label_encoders['user_id'].fit_transform(df['user_id'])
df['product_id'] = label_encoders['product_id'].fit_transform(df['product_id'])

# Store original user IDs for validation
original_user_ids = label_encoders['user_id'].inverse_transform(df['user_id'].unique())
original_user_ids
# Out:
# array([ 49125, 162867, 147243, ..., 144004, 101369,  70854], dtype=int64)

# %%
# Aggregate actions for each user_id and product_id pair
df = df.groupby(['user_id', 'product_id', 'Category_by_gender', 'Brand', 'Image_URL']).agg({'action': 'sum'}).reset_index()

# %%
# Split the data into train and test sets
train, test = train_test_split(df, test_size=0.2, random_state=42)

# %%
# Check if the original user_id is present in the dataset
print(f"Checking if User ID 49125 is in the original dataset: {'Yes' if 49125 in df['user_id'].unique() else 'No'}")
# Out:
# Checking if User ID 49125 is in the original dataset: No

# %%
# Create user-item interaction matrix
interaction_matrix = train.pivot_table(index='user_id', columns='product_id', values='action', aggfunc='sum').fillna(0)

# %%
# Compute the cosine similarity between users
user_similarity = cosine_similarity(interaction_matrix)

# %%
# Predict function with image URLs
def recommend_products(user_id, num_recommendations=5):
    # Check if the user_id exists in the original dataset
    if user_id not in original_user_ids:
        raise ValueError(f"User ID {user_id} not found in the dataset.")
    # Encode the user_id
    encoded_user_id = label_encoders['user_id'].transform([user_id])[0]
    
    # Check if the encoded user_id exists in the interaction matrix
    if encoded_user_id not in interaction_matrix.index:
        raise ValueError(f"Encoded User ID {encoded_user_id} not found in the interaction matrix.")
    
    similarity_scores = user_similarity[encoded_user_id]
    similar_users = np.argsort(-similarity_scores)[1:]  # Exclude the user itself

    # Aggregate products added to cart or purchased by similar users
    product_scores = np.zeros(interaction_matrix.shape[1])
    for similar_user in similar_users:
        product_scores += interaction_matrix.iloc[similar_user].values * similarity_scores[similar_user]

    # Exclude products the user has already interacted with
    user_interactions = interaction_matrix.iloc[encoded_user_id].values
    product_scores[user_interactions > 0] = 0

    # Get top recommendations
    recommended_product_ids = np.argsort(-product_scores)[:num_recommendations]
    recommended_product_ids = label_encoders['product_id'].inverse_transform(recommended_product_ids)
    
    # Get the category, brand, and image URL of recommended products
    recommended_products = df[df['product_id'].isin(recommended_product_ids)]
    return recommended_products[['product_id', 'Category_by_gender', 'Brand', 'Image_URL']].drop_duplicates()

# %%
user_id = 147243  # This is the original user ID
try:
    recommendations = recommend_products(user_id, num_recommendations=5)
    print("Recommendations:")
    print(recommendations)
except ValueError as e:
    print(e)
# Out:
# Recommendations:
#        product_id Category_by_gender               Brand  \
# 11             83                Men           performax
# 53             83                Men            schumann
# 57            120                Men         allen-solly
# 70             83              Women             aurelia
# 71             83              Women  avaasa-mix-n-match
# ...           ...                ...                 ...
# 31484          83                Men             netplay
# 31497          83                Men           performax
# 31511          83                Men                puma
# 31542          83              Women  avaasa-mix-n-match
# 31548          83              Women           performax
#
#                                                Image_URL
# 11     https://assets.ajio.com/medias/sys_master/root...
# 53     https://assets.ajio.com/medias/sys_master/root...
# 57     https://assets.ajio.com/medias/sys_master/root...
# 70     https://assets.ajio.com/medias/sys_master/root...
# 71     https://assets.ajio.com/medias/sys_master/root...
# ...                                                  ...
# 31484  https://assets.ajio.com/medias/sys_master/root...
# 31497  https://assets.ajio.com/medias/sys_master/root...
# 31511  https://assets.ajio.com/medias/sys_master/root...
# 31542  https://assets.ajio.com/medias/sys_master/root...
# 31548  https://assets.ajio.com/medias/sys_master/root...
#
# [1341 rows x 4 columns]

# %%
from IPython.display import display, HTML

def display_recommendations(recommendations):
    html = '<h2>Recommendations</h2>'
    for _, row in recommendations.iterrows():
        html += f"""
        <div style="margin-bottom: 20px;">
            <img src="{row['Image_URL']}" alt="Product Image" style="width:100px;height:100px;">
            <p><strong>Product ID:</strong> {row['product_id']}</p>
            <p><strong>Category by Gender:</strong> {row['Category_by_gender']}</p>
            <p><strong>Brand:</strong> {row['Brand']}</p>
        </div>
        """
    display(HTML(html))

# Display the recommendations with images
display_recommendations(recommendations)
# Out:
# <h2>Recommendations</h2>
#         <div style="margin-bottom: 20px;">
#             <img src="https://assets.ajio.com/medias/sys_master/root/20210219/5Vax/602ebc9eaeb2696981688349/-286Wx359H-450137600-nvyorn-MODEL.jpg" alt="Product Image" style="width:100px;height:100px;">
#             <p><strong>Product ID:</strong> 83</p>
#             <p><strong>Category by Gender:</strong> Men</p>
#             <p><strong>Brand:</strong> performax</p>
#         </div>
#
#         <div style="margin-bottom: 20px;">
#             <img src="https://assets.ajio.com/medias/sys_master/root/20210105/kBGM/5ff36a35aeb2694fd307cc65/-286Wx359H-450140379-tan-MODEL.jpg" alt="Product Image" style="width:100px;height:100px;">
#             <p><strong>Product ID:</strong> 83</p>
#             <p><strong>Category by Gender:</strong> Men</p>
#             <p><strong>Brand:</strong> schumann</p>
#         </div>
#
#         <div style="margin-bottom: 20px;">
#             <img src="https://assets.ajio.com/medias/sys_master/root/hbc/h28/16729167724574/-286Wx359H-450138188-navy-MODEL.jpg" alt="Product Image" style="width:100px;height:100px;">
#             <p><strong>Product ID:</strong> 120</p>
#             <p><strong>Category by Gender:</strong> Men</p>
#             <p><strong>Brand:</strong> allen-solly</p>
#         </div>
#
#         <div style="margin-bottom: 20px;">
#             <img src="https://assets.ajio.com/medias/sys_master/root/20211115/HOKW/61927b0ff997ddf8f105ba07/-286Wx359H-441158324-blue-MODEL.jpg" alt="Product Image" style="width:100px;height:100px;">
#             <p><strong>Product ID:</strong> 83</p>
#             <p><strong>Category by Gender:</strong> Women</p>
#             <p><strong>Brand:</strong> aurelia</p>
#         </div>
#
#         <div style="margin-bottom: 20px;">
#             <img src="https://assets.ajio.com/medias/sys_master/root/20210818/1EvJ/611d20ebaeb269a268770393/-286Wx359H-441124869-peach-MODEL.jpg" alt="Product Image" style="width:100px;height:100px;">
#             <p><strong>Product ID:</strong> 83</p>
#             <p><strong>Category by Gender:</strong> Women</p>
#             <p><strong>Brand:</strong> avaasa-mix-n-match</p>
#         </div>
#
#         <div style="margin-bottom: 20px;">
#             <img src="https://assets.ajio.com/medias/sys_master/root/hf1/h52/16496477437982/-286Wx359H-441038484-mediumblue-MODEL.jpg" alt="Product Image" style="width:100px;height:100px;">
#             <p><strong>Product ID:</strong> 83</p>
#             <p><strong>Category by Gender:</strong> Men</p>
#             <p><strong>Brand:</strong> dnmx</p>
#         </div>
#
#         <div style="margin-bottom: 20px;">
#             <img src="https://assets.ajio.com/medias/sys_master/root/20220315/svJW/622f8c4af997dd03e211c8bc/-286Wx359H-441135991-navy-MODEL.jpg" alt="Product Image" style="width:100px;height:100px;">
#             <p><strong>Product ID:</strong> 83</p>
#             <p><strong>Category by Gender:</strong> Women</p>
#             <p><strong>Brand:</strong> teamspirit</p>
#         </div>
#
#         <div style="margin-bottom: 20px;">
#             <img src="https://assets.ajio.com/medias/sys_master/root/hc9/h5f/10247840628766/-286Wx359H-440762638-coral-OUTFIT.jpg" alt="Product Image" style="width:100px;height:100px;">
#             <p><strong>Product ID:</strong> 83</p>
#             <p><strong>Category by Gender:</strong> Men</p>
#             <p><strong>Brand:</strong> dnmx</p>
#         </div>
#
#         <div style="margin-bottom: 20px;">
#             <img src="https://assets.ajio.com/medias/sys_master/root/20211118/Q0Jy/619560d0aeb2690110caab7c/-286Wx359H-441192131-yellow-MODEL.jpg" alt="Product Image" style="width:100px;height:100px;">
#             <p><strong>Product ID:</strong> 83</p>
#             <p><strong>Category by Gender:</strong> Men</p>
#             <p><strong>Brand:</strong> lee-cooper</p>
#         </div>
#
#         <div style="margin-bottom: 20px;">
#             <img src="https://assets.ajio.com/medias/sys_master/root/20201205/IEH4/5fca8cc1f997dd8c83b906ed/-286Wx359H-441069665-mustard-MODEL.jpg" alt="Product Image" style="width:100px;height:100px;">
#             <p><strong>Product ID:</strong> 83</p>
#             <p><strong>Category by Gender:</strong> Women</p>
#             <p><strong>Brand:</strong> biba</p>
#         </div>
#
#         <div style="margin-bottom: 20px;">
#             <img src="https://assets.ajio.com/medias/sys_master/root/20220308/NYb4/62267d1baeb26921afcc5fce/-286Wx359H-441200232-green-MODEL.jpg" alt="Product Image" style="width:100px;height:100px;">
#             <p><strong>Product ID:</strong> 83</p>
#             <p><strong>Category by Gender:</strong> Women</p>
#             <p><strong>Brand:</strong> w</p>
#         </div>
#
#         <div style="margin-bottom: 20px;">
#             <img src="https://assets.ajio.com/medias/sys_master/root/h88/h45/10713187778590/-286Wx359H-440773578-offwhite-MODEL.jpg" alt="Product Image" style="width:100px;height:100px;">
#             <p><strong>Product ID:</strong> 83</p>
#             <p><strong>Category by Gender:</strong> Women</p>
#             <p><strong>Brand:</strong> w</p>
#         </div>
#
#         <div style="margin-bottom: 20px;">
#             <img src="https://assets.ajio.com/medias/sys_master/root/h86/h4f/10532526882846/-286Wx359H-440803395-pink-MODEL.jpg" alt="Product Image" style="width:100px;height:100px;">
#             <p><strong>Product ID:</strong> 120</p>
#             <p><strong>Category by Gender:</strong> Women</p>
#             <p><strong>Brand:</strong> aurelia</p>
#         </div>
#
#         <div style="margin-bottom: 20px;">
#             <img src="https://assets.ajio.com/medias/sys_master/root/h25/h51/10791845167134/-286Wx359H-440733466-white-MODEL.jpg" alt="Product Image" style="width:100px;height:100px;">
#             <p><strong>Product ID:</strong> 120</p>
#             <p><strong>Category by Gender:</strong> Women</p>
#             <p><strong>Brand:</strong> w</p>
#         </div>
#
#         <div style="margin-bottom: 20px;">
#             <img src="https://assets.ajio.com/medias/sys_master/root/20220217/TGYM/620d4718aeb26921af9b8866/-286Wx359H-441137022-olive-MODEL.jpg" alt="Product Image" style="width:100px;height:100px;">
#             <p><strong>Product ID:</strong> 83</p>
#             <p><strong>Category by Gender:</strong> Women</p>
#             <p><strong>Brand:</strong> rio</p>
#         </div>
#
#         <div style="margin-bottom: 20px;">
#             <img src="https://assets.ajio.com/medias/sys_master/root/20220225/jBeK/6217db5faeb26921afb604fb/-286Wx359H-441297357-burgandy-MODEL.jpg" alt="Product Image" style="width:100px;height:100px;">
#             <p><strong>Product ID:</strong> 120</p>
#             <p><strong>Category by Gender:</strong> Women</p>
#             <p><strong>Brand:</strong> iscenery-by-vero-moda</p>
#         </div>
#
#         <div style="margin-bottom: 20px;">
#             <img src="https://assets.ajio.com/medias/sys_master/root/20220107/PKJs/61d735aef997dd662312feb5/-286Wx359H-441131888-white-MODEL.jpg" alt="Product Image" style="width:100px;height:100px;">
#             <p><strong>Product ID:</strong> 83</p>
#             <p><strong>Category by Gender:</strong> Women</p>
#             <p><strong>Brand:</strong> dnmx</p>
#         </div>
#
#         <div style="margin-bottom: 20px;">
#             <img src="https://assets.ajio.com/medias/sys_master/root/20201126/DpnM/5fbedf91f997dd8c83aa0cb1/-286Wx359H-441103476-mustard-MODEL.jpg" alt="Product Image" style="width:100px;height:100px;">
#             <p><strong>Product ID:</strong> 120</p>
#             <p><strong>Category by Gender:</strong> Women</p>
#             <p><strong>Brand:</strong> rio</p>
#         </div>
#
#         <div style="margin-bottom: 20px;">
#             <img src="https://assets.ajio.com/medias/sys_master/root/20211119/PDPL/6197c32ff997ddf8f10f285d/-286Wx359H-441121570-darkgrey-MODEL.jpg" alt="Product Image" style="width:100px;height:100px;">
#             <p><strong>Product ID:</strong>

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics.pairwise import cosine_similarity

from PIL import Image
import matplotlib.pyplot as plt
from sklearn.metrics.pairwise import cosine_similarity
from scipy.sparse import csr_matrix

# %%
dtype_spec = {
    'department_id': 'str',
    'Brand': 'str',
    'Description': 'str',
    'Image_URL': 'str',
    'Category_by_gender': 'str'
}

df2 = pd.read_csv('projectdataset2.csv', dtype=dtype_spec, low_memory=False)
# Use only the first 31,583 rows
df2 = df2.head(31583)

# %%
action_map = {
    'view': 1,
    'add_to_cart': 2,
    'purchase': 3
}
df['action'] = df['action'].map(action_map)

# %%
def get_recommendations(user_id):
    # Assuming a recommendation logic is implemented here
    user_data = fashion_data[fashion_data['user_id'] == user_id]
    if user_data.empty:
        return None
    # Here, for simplicity, returning top 5 rated products of the user
    return user_data.sort_values(by='ratings', ascending=False)['productId'].head(5).tolist()

# %%
# Calculate trendiness based on recent purchases or other relevant metrics
# Calculate trendiness based on recent purchases or ratings count
df2['trendiness'] = df2.groupby('product_id')['ratings'].transform('count')
top_n_products = 10  # Number of top trending products to recommend
top_trending_products = df2[['product_id', 'Image_URL', 'trendiness']].drop_duplicates().nlargest(top_n_products, 'trendiness')
#df2['trendiness'] = df2.groupby('product_id')['ratings'].count()  # Example: Using purchase count as a proxy for trendiness
#top_n_products = 10  # Number of top trending products to recommend
#top_trending_products = df2.nlargest(top_n_products, 'trendiness')['product_id']

# %%
# Function to display images from the Image_URL column
def display_trending_fashion_images(top_trending_products):
    html = '<h2>Trending Fashion</h2>'
    for _, row in top_trending_products.iterrows():
        html += f"""
        <div style="display:inline-block; margin: 10px;">
            <img src="{row['Image_URL']}" alt="Product Image" style="width:150px;height:150px;">
            <p><strong>Product ID:</strong> {row['product_id']}</p>
        </div>
        """
    display(HTML(html))

# %%
# Display trending fashion images
display_trending_fashion_images(top_trending_products)
# Out:
# <h2>Trending Fashion</h2>
#         <div style="display:inline-block; margin: 10px;">
#             <img src="https://assets.ajio.com/medias/sys_master/root/20220408/MBlw/624f322ff997dd03e24ddbd9/-286Wx359H-441134769-darkblue-MODEL.jpg" alt="Product Image" style="width:150px;height:150px;">
#             <p><strong>Product ID:</strong> 24</p>
#         </div>
#
#         <div style="display:inline-block; margin: 10px;">
#             <img src="https://assets.ajio.com/medias/sys_master/root/20220114/L59s/61e1a773f997dd66232258c5/-286Wx359H-441129778-jetblack-MODEL.jpg" alt="Product Image" style="width:150px;height:150px;">
#             <p><strong>Product ID:</strong> 24</p>
#         </div>
#
#         <div style="display:inline-block; margin: 10px;">
#             <img src="https://assets.ajio.com/medias/sys_master/root/20220120/krOD/61e98207aeb2695cdd2243e5/-286Wx359H-441129796-ltgreen-MODEL.jpg" alt="Product Image" style="width:150px;height:150px;">
#             <p><strong>Product ID:</strong> 24</p>
#         </div>
#
#         <div style="display:inline-block; margin: 10px;">
#             <img src="https://assets.ajio.com/medias/sys_master/root/20220322/V40A/6238dd87f997dd03e2248011/-286Wx359H-441113673-mustard-MODEL.jpg" alt="Product Image" style="width:150px;height:150px;">
#             <p><strong>Product ID:</strong> 24</p>
#         </div>
#
#         <div style="display:inline-block; margin: 10px;">
#             <img src="https://assets.ajio.com/medias/sys_master/root/20220315/dLrB/622f97caaeb26921afd7ba45/-286Wx359H-441134836-jetblack-MODEL.jpg" alt="Product Image" style="width:150px;height:150px;">
#             <p><strong>Product ID:</strong> 24</p>
#         </div>
#
#         <div style="display:inline-block; margin: 10px;">
#             <img src="https://assets.ajio.com/medias/sys_master/root/20211202/kix4/61a7f871aeb2690110eafbe3/-286Wx359H-441133896-olive-MODEL.jpg" alt="Product Image" style="width:150px;height:150px;">
#             <p><strong>Product ID:</strong> 24</p>
#         </div>
#
#         <div style="display:inline-block; margin: 10px;">
#             <img src="https://assets.ajio.com/medias/sys_master/root/20220407/emvY/624ddd31f997dd03e24bd624/-286Wx359H-441143985-white-MODEL.jpg" alt="Product Image" style="width:150px;height:150px;">
#             <p><strong>Product ID:</strong> 24</p>
#         </div>
#
#         <div style="display:inline-block; margin: 10px;">
#             <img src="https://assets.ajio.com/medias/sys_master/root/20220208/bCgf/62016f34aeb26921af8d5d45/-286Wx359H-441136488-white-MODEL.jpg" alt="Product Image" style="width:150px;height:150px;">
#             <p><strong>Product ID:</strong> 24</p>
#         </div>
#
#         <div style="display:inline-block; margin: 10px;">
#             <img src="https://assets.ajio.com/medias/sys_master/root/20211202/oM4k/61a7f434aeb2690110eaeaad/-286Wx359H-441135822-jetblack-MODEL.jpg" alt="Product Image" style="width:150px;height:150px;">
#             <p><strong>Product ID:</strong> 24</p>
#         </div>
#
#         <div style="display:inline-block; margin: 10px;">
#             <img src="https://assets.ajio.com/medias/sys_master/root/20220222/2HCt/6213f1cbaeb26921afa70e48/-286Wx359H-441132316-rust-MODEL.jpg" alt="Product Image" style="width:150px;height:150px;">
#             <p><strong>Product ID:</strong> 24</p>
#         </div>
